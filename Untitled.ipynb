# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

img = Image.open('images/neko_girl_1.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=225x225 at 0x1FD5E426A90>

# %%
np.array(img).shape
# Out:
# (225, 225, 3)

# %%
import base64 
with open("images/neko_girl_1.jpg", "rb") as f:
    data = f.read()
#     encoded_string = base64.encodestring(data)
    encoded_string = base64.b64encode(data)

# %%
import matplotlib.image as mpimg
# plt.imshow(mpimg.imread(data))

# %%
encoded_string
# Out:
# b'...'

# %%
# base64.decodestring(encoded_string)
# encoded_string.decode('base64')
img2 = base64.b64decode(encoded_string)

# %%
with open('images/test.jpg', 'wb') as f:
    f.write(img2)

# %%
import io 

i = io.BytesIO(img2)
i = mpimg.imread(i, format='JPG')

# plt.imshow(i, interpolation='nearest')
plt.imshow(i)
plt.show()

# %%
i
# Out:
# array([[[114,  95,  81],
#         [113,  94,  80],
#         [113,  94,  80],
#         ...,
#         [109,  90,  76],
#         [109,  90,  76],
#         [111,  89,  76]],
#
#        [[117,  99,  85],
#         [117,  99,  85],
#         [117,  99,  85],
#         ...,
#         [107,  89,  75],
#         [107,  89,  75],
#         [110,  88,  75]],
#
#        [[112,  94,  80],
#         [112,  94,  80],
#         [112,  94,  80],
#         ...,
#         [105,  87,  73],
#         [105,  87,  73],
#         [108,  86,  73]],
#
#        ...,
#
#        [[238, 232, 220],
#         [237, 231, 219],
#         [237, 231, 219],
#         ...,
#         [244, 240, 231],
#         [245, 241, 232],
#         [245, 242, 235]],
#
#        [[237, 231, 219],
#         [237, 231, 219],
#         [236, 230, 218],
#         ...,
#         [244, 240, 231],
#         [244, 240, 231],
#         [244, 241, 234]],
#
#        [[233, 231, 218],
#         [233, 231, 218],
#         [232, 230, 217],
#         ...,
#         [242, 241, 236],
#         [242, 241, 236],
#         [243, 243, 235]]], dtype=uint8)
